# %% [markdown]
# # Implementación de estrategias de aprendizaje activo en el área de Mecánica Computacional del Departamento de Ingeniería Civil
# <br>
#
# ## Juan David Gómez
# ### Nicolás Guarín-Zapata, Camilo Vieira, Juan David Ortega
#
# <img style="float: right;"
#      src="./img/logo.svg"
#      width="320"
#      height="50">
#
#
#
# <br>
# Marzo 24 - Departamento de Ingeniería Civil
# <br>

# %% [markdown]
# <img style="float: center;"
#      src="./img/collage.png"
#      width="2000"
#      height="50">

# %% [markdown]
# **Nota:** Esta es una presentación de diapositivas en Jupyter Notebooks para una mejor visualización de la presentación. Se recomienda instalar RISE para convertir losNBs en presentaciones en vivo.
# https://github.com/damianavila/RISE

# %% [markdown]
# # ¿Por qué cambiar? Una visión personal
#
#
# - Frustración.
#
# - Conociendo a Juanpa.
#
# - Lo que me dijo Geovany Bedoya un día.
#
#   "Me levanto todos los días a hacer mi trabajo de la mejor manera posible."

# %% [markdown]
# # ¿Qué es aprendizaje activo?
#
# - Lo que resulta de un mal profesor y un buen estudiante.
# - Lo que hacía Juan "Malo".

# %% [markdown]
# > "Proceso que involucra a los estudiantes en alguna actividad que los obliga a reflexionar acerca de ideas y de como usar esas ideas", Michael (2006).

# %% [markdown]
# > "Método que involucra a los estudiantes en el proceso de aprendizaje a través de
# actividades y/o discusiones en el aula, en comparación con la acción de escuchar pasivamente a un
# experto. El aprendizaje activo enfatiza el pensamiento de orden superior y frecuentemente
# implica trabajo de grupo", Freeman et al (2014)

# %% [markdown]
# <tbody>
# <tr class="odd">
# <td style="text-align: left;"><strong>Pasivo</strong></td>
# <td style="text-align: left;"><strong>Activo</strong></td>
# </tr>
# <tr class="even">
# <td style="text-align: left;">Leer sobre un tema</td>
# <td style="text-align: left;">Resolver problemas</td>
# </tr>
# <tr class="odd">
# <td style="text-align: left;">Mirar un video</td>
# <td style="text-align: left;">Discutir el tema de un video</td>
# </tr>
# <tr class="even">
# <td style="text-align: left;">Atender una clase</td>
# <td style="text-align: left;">Tratar de dictar una clase</td>
# </tr>
# </tbody>

# %% [markdown]
# ## Evidencias
#
# Hake (1998); Crouch y Mazur (2001); Deslauriers et al.(2011); Deslauriers y Wieman (2011); Fraser et al.(2014); Freeman et al.(2014).
#
# - Mayor esfuerzo cognitivo de parte del estudiante.
# - Mejor aprendizaje conceptual.
# - Mayor responsabilidad en el estudiante.
# - Promueve desarrollo de aplicación efectiva del conocimiento, análisis, capacidad de síntesis.
# - Procesos de aprendizaje de mayor profundidad.
# - Justifica la asistencia a clasee.

# %% [markdown]
# # Marco conceptual
#
# Para diseñar la estrategia de clase invertida con aprendizaje activo se adoptó el siguiente marco conceptual:
#
# <center>
#     <img src="img/marco.png"
#          alt="Marco conceptual de diseño."
#          style="width:800px">
# </center>

# %% [markdown]
# ## Modelo de aprendizaje cognitivo
#
# Permite a los estudiantes usar estrategias cognitivas y meta-cognitivas para utilizar, administrar y descubrir conocimiento.
#
# <center>
#     <img src="img/esquema_aprendizaje_cognitivo_bloques.svg"
#          alt="Diagrama de aprendizaje activo."
#          style="width:1000px">
# </center>

# %% [markdown]
# ## ¿ Que se implementó?
#
# SolidsPy: Código por elementos finitos basado en Python para la construcción de ambientes de aprendizaje computacional.
#
# - Los ambientes de aprendizaje corresponden a cuadernos tradicionales de notas de clase pero con la integración de elementos interactivos que adicionan visualización, modelación, simulación y experimentación numérica en el aula de clase y en tiempo real.
#
# - Los ambientes de aprendizaje permiten diseñar clases en modelos de aula invertida con aprendizaje activo.
#
# - Extendibles a otras materias (Mecánica de sólidos, análisis estructral, mecánica de suelos, mecánica de fluidos).

# %% [markdown]
# ## Recursos
#
# - SolidsPy (Simulador por elementos finitos basado en Python).
# - Cuadernillos digitales interactivos (Jupyter Notebooks).
# - Notas de clase (IC0285, IC0283 , IC0602).
# - Actividades.
# - Rúbricas.
# - Proyectos.

# %% [markdown]
# ### Repositorio de GitHub (https://github.com/AppliedMechanics-EAFIT)
#
# <img style="float: center;" src="./img/github.png" width="800" height="50" >

# %% [markdown]
# Mostrar REPO de Mecánica Aplicada enfatizando en "impacto" de SolidsPy (Seguidores, Downloads, etc)

# %% [markdown]
# # SolidsPy: Código por elementos finitos con fines de aprendizaje activo

# %% [markdown]
# ### Atributos
#
# - Permite resolver sistemas con más de 6 millones de grados de libertad en un computador portátil para para elasticidad plana, armaduras y pórticos.
#
# - Es un simulador. Para clases conceptuales donde el objetivo principal es la física.

# %% [markdown]
# ### Atributos
#
# - Es modular. Para clases procedimentales donde importan los métodos numéricos o los algoritmos.
#
# - Es un pseudo-lenguaje (Permite construir scripts para clases donde lo importante es una secuancia de simulación particular, e.g., Cercha de von Mises).
#
# - Es un paquete de Python (Integrable desde cualquier programa incluyendo Jupyter Notebooks).

# %% [markdown]
# ### Impacto externo
#
# - Crecible (No-linealidades, Análisis dinámico, transferencia de calor, placas, análisis de sensibilidades).
#
# - 100 seguidores en GitHub, 58 descargas por mes, 2 artículos internacionales.
#
# - Nie Z, Jiang H, Kara LB. Stress Field Prediction in Cantilevered Structures Using Convolutional Neural Networks. Journal of Computing and Information Science in Engineering. 2020 Mar 1;20(1).

# %% [markdown]
# ### Impacto externo
#
# - De Los Santos, Pedro., Vignaud, Alejo and Mota, Francisco. Desarrollo de una librería en Python para el análisis estructural utilizando elementos finitos. Memorias del XXV Congreso Interncional Anual de la SOMIM. Sinaloa, Mexico, septiembre 2019.
#
# - Una tesis de Maestría en Ingeniería.

# %% [markdown]
# ## Ejemplo de clase conceptual (Mecánica de los Medios Continuos)
#
# <img style="float: left;"
#      src="./img/presa_dim.svg"
#      width="300" >
#
# <img style="float: center;"
#      src="./img/presa.svg"
#      width="320" >

# %% [markdown]
# ### Actividades
#
# **1.** Asumiendo que $A_c = A_p$:
#
# **(i)** Determine la respuesta de la presa a una carga lateral en su cresta.
#
# **(ii)** Determine la respuesta de la presa a una carga uniformemente distribuida de magnitud $p = \gamma H_p$ sobre la superficie de la presa en contacto con el fluido.
#
# **(iii)** Determine la respuesta de la presa a una carga con variación lineal (equivalente al empuje del agua sobre la presa).

# %% [markdown]
# Compare los resultados de cada uno de los análisis con la respectiva solución de resistencia de materiales (teoría de vigas). Adicionalmente:
#
# **(a)** Describa los cambios de la solución entre los casos (i) al (iii).
#
# **(b**) Usando argumentos de tipo mecánico explique los cambios identificados en el numeral anterior.

# %% [markdown]
# **2.** Repita el análisis (iii) pero adicionando ahora fuerzas de cuerpo correspondientes al peso propio del concreto. Asuma que el peso específico del concreto es _2.3 veces el del fluido_.
#
# **3.** Considere ahora 3 valores diferentes para el ancho de la pata $A_p$. Usando argumentos de tipo mecánico explique el efecto de este parámetro en la respuesta.
#
# **4.** Usando los parámetros geométricos y propiedades de los materiales dadas al inicio del NB indique si la presa falla o no falla. En caso de que esta falle indique la localización de los puntos de falla y los respectivos modos de falla. En caso de que esta no presente falla indique el factor de seguridad en cada caso.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import meshio
import solidspy.preprocesor as msh
import solidspy.assemutil as ass
import solidspy.postprocesor as pos
import solidspy.solutil as sol
import aux_functions as aux

# %%
# %run -i files/snippet1.py
H_p   = 100.0
A_c   = 30.0
gamma = 9.8e3
body = True
cargas = aux.dam_loading(cells, cell_data, 3000, points, 0.0, gamma, H_p)
#cargas = aux.uniform_loading(cells, cell_data, 3000, points, gamma, H_p)
np.savetxt("files/Dloads.txt", cargas, fmt=("%d", "%.3g", "%.3g"))
# %run -i files/snippet2.py
# %run -i files/snippet3.py

# %%
E_nodes, S_nodes = pos.strain_nodes(nodes, elements, mats, UC)
pos.fields_plot(elements, nodes, UC, S_nodes=S_nodes)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
eigs1, eigs2, vecs1, vecs2 = pos.principal_dirs(S_nodes)
pos.plot_node_field(eigs1, nodes, elements)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Investigación
#
# Se esta realizando un proyecto para medir el impacto de la transformación a través de encuestas, entrevistas, think-all-outs.
#
#
# - Vieira, Camilo and Gomez, Juan. Integrating Computation into a Civil Engineering Curriculum: Instructions at a Colombian Higher Education Institution. Proceedings of the 2019. Research in Engineering Education Symposium (REES). July 10-12, Cape Town, South Africa.
#
#
# - Gomez, Juan, Guarín-Zapata, Nicolás, Vieira, Camilo and Ortega-Alvarez, Juan. Jupyter notebooks y otros recursos para el aprendizaje activo en el área de Mecánica Computacional de la Universidad EAFIT. Experiencias significativas de aprendizaje en el aula. Universidad Nacional, Medellín, Colombia. Noviembre del 2019.
